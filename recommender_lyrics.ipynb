# %% [markdown]
# # 1. Choosing the song for comparison

# %%
import os
import re
import pandas as pd

# %%
# printing a list of titles in lexicographic order with division by the first letter

def print_lexic_order_with_first_letter(list_list):
    list_list = sorted(list_list)
    first_letter = ''
    for s in list_list:
        if s[0] != first_letter:
            first_letter = s[0]
            print()
            print(str.upper(first_letter))
        print(s)
    return 1

# %%
'''
To view the collection
'''

path = "discography/"
dir_list = os.listdir(path)
artist_list = [re.sub("_discography_allthelyrics.csv", "", d) for d in dir_list if "_discography_allthelyrics.csv" in d]

print_lexic_order_with_first_letter(artist_list)
# Out:
# B
# black_sabbath
# blondie
# bob_dylan
#
# D
# depeche_mode
# dio
# doors
#
# E
# elf
#
# F
# florence_the_machine
# franz_ferdinand
#
# G
# guns_n_roses
#
# I
# imagine_dragons
#
# K
# kasabian
#
# L
# lana_del_rey
#
# M
# muse
#
# Q
# queen
#
# R
# rainbow
# roxette
#
# U
# u2
#
# W
# within_temptation
# 1

# %%
'''
To choose the artist
'''

target_artist = 'florence_the_machine'
# 'florence_the_machine'

# %%
discography_df = pd.read_csv('discography/' + target_artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8')
discography_df.head()
# Out:
#                       song                                               link  \
# 0         Addicted To Love  https://www.allthelyrics.com/lyrics/florence_t...
# 1  All This And Heaven Too  https://www.allthelyrics.com/lyrics/florence_t...
# 2        Between Two Lungs  https://www.allthelyrics.com/lyrics/florence_t...
# 3                 Blinding  https://www.allthelyrics.com/lyrics/florence_t...
# 4            Breaking Down  https://www.allthelyrics.com/lyrics/florence_t...
#
#    album                                             lyrics
# 0      -  The lights are on, but you're not home\nYour m...
# 1      -  [Florence]\nAnd the heart is hard to translate...
# 2  Lungs  Between two lungs it was released\nThe breath ...
# 3  Lungs  Seems that I have been held in some dreaming s...
# 4      -  All alone\nIt was always there you see\nAnd ev...

# %%
'''
To view the discography
'''

songs = list(discography_df['song'])

print_lexic_order_with_first_letter(songs)
# Out:
# A
# Addicted To Love
# All This And Heaven Too
#
# B
# Between Two Lungs
# Blinding
# Breaking Down
#
# C
# Cosmic Love
#
# D
# Dog Days Are Over
# Drumming Song
#
# G
# Girl With One Eye
#
# H
# Heartlines
# Hurricane Drunk
#
# I
# I'm Not Calling You A Liar
#
# K
# Kiss With A Fist
#
# L
# Leave My Body
# Lover To Lover
#
# M
# My Boy Builds Coffins
#
# N
# Never Let Me Go
# No Light No Light
#
# O
# Only If For A Night
#
# R
# Rabbit Heart (Raise It Up)
#
# S
# Seven Devils
# Shake It Out
# Spectrum
#
# W
# What The Water Gave Me
#
# Y
# You've Got The Love
# 1

# %%
'''
To choose the song:
'''

target_song = 'No Light No Light'

# %% [markdown]
# # 2. Creating the full lyrics base

# %%
full_discography_list = []

for artist in artist_list:
    discography_df = pd.read_csv('discography/' + artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8')
    discography_df['artist'] = artist
    discography_df['key'] = discography_df.apply(lambda x: x['artist'] + '__' + '_'.join(x['album'].split()) + '__' + '_'.join(x['song'].split()), axis=1)
# .strip(",[]()-?!'")
    full_discography_list.append(discography_df)
    
full_discography_df = pd.concat(full_discography_list, axis=0)[['key', 'artist', 'album', 'song', 'lyrics', 'link']]
# full_discography_df

# %%
full_discography_df2 = full_discography_df.set_index('key')
full_discography_df2.head()
# Out:
#                                                    artist  \
# key
# doors__An_American_Prayer__A_Feast_Of_Friends       doors
# doors__Absolutely_Live__A_Little_Game               doors
# doors__The_Doors__Adolf_Hitler                      doors
# doors__-__Adolph_Hitler_(Live_At_The_Boston_Gar...  doors
# doors__Best_of_the_Doors_[2000_Double_Disc]__Al...  doors
#
#                                                                                    album  \
# key
# doors__An_American_Prayer__A_Feast_Of_Friends                         An American Prayer
# doors__Absolutely_Live__A_Little_Game                                    Absolutely Live
# doors__The_Doors__Adolf_Hitler                                                 The Doors
# doors__-__Adolph_Hitler_(Live_At_The_Boston_Gar...                                     -
# doors__Best_of_the_Doors_[2000_Double_Disc]__Al...  Best of the Doors [2000 Double Disc]
#
#                                                                                                  song  \
# key
# doors__An_American_Prayer__A_Feast_Of_Friends                                      A Feast Of Friends
# doors__Absolutely_Live__A_Little_Game                                                   A Little Game
# doors__The_Doors__Adolf_Hitler                                                           Adolf Hitler
# doors__-__Adolph_Hitler_(Live_At_The_Boston_Gar...  Adolph Hitler (Live At The Boston Gardens, Bos...
# doors__Best_of_the_Doors_[2000_Double_Disc]__Al...                                       Alabama Song
#
#                                                                                                lyrics  \
# key
# doors__An_American_Prayer__A_Feast_Of_Friends       Wow, I'm sick of doubt\nLive in the light of c...
# doors__Absolutely_Live__A_Little_Game               Once I had a little game\nI liked to crawl bac...
# doors__The_Doors__Adolf_Hitler                      Adolf Hitler is still alive\nOoooogh - sssssh\...
# doors__-__Adolph_Hitler_(Live_At_The_Boston_Gar...  Adolf Hitler is still alive\nOoooogh - sssssh\...
# doors__Best_of_the_Doors_[2000_Double_Disc]__Al...  Well, show me the way, To the next whiskey bar...
#
#                                                                                                  link
# key
# doors__An_American_Prayer__A_Feast_Of_Friends       https://www.allthelyrics.com/lyrics/doors/a_fe...
# doors__Absolutely_Live__A_Little_Game               https://www.allthelyrics.com/lyrics/doors/a_li...
# doors__The_Doors__Adolf_Hitler                      https://www.allthelyrics.com/lyrics/doors/adol...
# doors__-__Adolph_Hitler_(Live_At_The_Boston_Gar...  https://www.allthelyrics.com/lyrics/doors/adol...
# doors__Best_of_the_Doors_[2000_Double_Disc]__Al...  https://www.allthelyrics.com/lyrics/doors/alab...

# %%
target_lyrics_df = full_discography_df2[
    (full_discography_df2['artist'] == target_artist) &
#     full_discography_df2[''] == album_title &
    (full_discography_df2['song'] == target_song)
]

target_lyrics_df
# Out:
#                                                           artist album  \
# key
# florence_the_machine__-__No_Light_No_Light  florence_the_machine     -
#
#                                                          song  \
# key
# florence_the_machine__-__No_Light_No_Light  No Light No Light
#
#                                                                                        lyrics  \
# key
# florence_the_machine__-__No_Light_No_Light  You are the hole in my head\nYou are the space...
#
#                                                                                          link
# key
# florence_the_machine__-__No_Light_No_Light  https://www.allthelyrics.com/lyrics/florence_t...

# %%
target_lyrics_df.index[0]
# Out:
# 'florence_the_machine__-__No_Light_No_Light'

# %%
# full_discography_df3 = full_discography_df2['lyrics']
# print(full_discography_df3.head())

# target_lyrics_df3 = target_lyrics_df['lyrics']
# print(target_lyrics_df3.head())

# %% [markdown]
# # 3. Text-based recommender

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def to_recommend_lyrics(df, target_key):
    # Instantiate the vectorizer object and transform the plot column
    vectorizer = TfidfVectorizer(max_df=0.7, min_df=2)
    vectorized_data = vectorizer.fit_transform(df['lyrics'])

    # Create Dataframe from TF-IDFarray
    tfidf_df = pd.DataFrame(vectorized_data.toarray(), columns=vectorizer.get_feature_names_out())

    # Assign the movie titles to the index and inspect
    tfidf_df.index = df.index
#     print(tfidf_df.head())

    # Create the array of cosine similarity values
    cosine_similarity_array = cosine_similarity(tfidf_df)

    # Wrap the array in a pandas DataFrame
    cosine_similarity_df = pd.DataFrame(cosine_similarity_array, index=tfidf_df.index, columns=tfidf_df.index)
#     print(cosine_similarity_df.head())

    # Find the values for the movie Rio
    cosine_similarity_series = cosine_similarity_df.loc[target_key]

    # Sort these values highest to lowest
    ordered_similarities = cosine_similarity_series.sort_values(ascending=False)

    # Print the results
#     print(ordered_similarities)
    return ordered_similarities


similar_df = to_recommend_lyrics(full_discography_df2, target_lyrics_df.index[0])
# similar_df

# %%
def top_of_similarity(similar_df, threshold):
    similar_df_head = similar_df[similar_df.values >= threshold]
    similar_df_head2 = pd.DataFrame(similar_df_head)
    similar_df_head2.columns = ['similarity_score']
    
    return similar_df_head2

# %%
similar_df_head2 = top_of_similarity(similar_df, 0.2)
similar_df_head2.join(full_discography_df2).reset_index(drop=True)[['similarity_score','artist','album','song']]
# .iloc[:, :4]
# Out:
#     similarity_score                artist  \
# 0           1.000000  florence_the_machine
# 1           0.266883             bob_dylan
# 2           0.261312             bob_dylan
# 3           0.235382                    u2
# 4           0.235279                 queen
# 5           0.215884                    u2
# 6           0.214731                    u2
# 7           0.212173          depeche_mode
# 8           0.207505             bob_dylan
# 9           0.207148                    u2
# 10          0.201460               rainbow
# 11          0.200866               blondie
# 12          0.200866               blondie
#
#                                       album  \
# 0                                         -
# 1                         Nashville Skyline
# 2                         Slow Train Coming
# 3                               Fire/R.O.K.
# 4                                  Innuendo
# 5           Passengers: Original Soundtrack
# 6           How To Dismantle An Atomic Bomb
# 7                         Black Celebration
# 8                          Empire Burlesque
# 9                    The Unforgettable Fire
# 10                    Long Live Rock'n'Roll
# 11                      Def Dumb And Blonde
# 12  Most Of All - The Best Of Deborah Harry
#
#                                            song
# 0                             No Light No Light
# 1                                One More Night
# 2                                Precious Angel
# 3                  The Ocean (Live From Boston)
# 4                                 I Want It All
# 5                                          Slug
# 6                       Original Of The Species
# 7                                   If You Want
# 8                     Something's Burning, Baby
# 9                                           Bad
# 10                           Sensitive To Light
# 11                              I Want That Man
# 12  I Want That Man (Allanah Currie-tom Bailey)

# %% [markdown]
# # 4. [!!!] User-profile Recommender

# %%
'''
define the set of your favourite songs
and 
learn the most similar songs from the rest of the full discography
'''

# %%
my_favourite_songs_list = [
    ['queen', "", "Don't Stop Me Now"],
    ['queen', "", "Under Pressure"],
    ['lana_del_rey', "", "Blue Jeans"],
    ['rainbow', "", "Stargazer"],
    ['guns_n_roses', "", "You Could Be Mine"]
]

# %%
my_favourite_songs_df = pd.DataFrame(my_favourite_songs_list)
my_favourite_songs_df.columns = ['artist', 'album_0', 'song']
my_favourite_songs_df = my_favourite_songs_df.drop(['album_0'], axis=1)
my_favourite_songs_df
# Out:
#          artist               song
# 0         queen  Don't Stop Me Now
# 1         queen     Under Pressure
# 2  lana_del_rey         Blue Jeans
# 3       rainbow          Stargazer
# 4  guns_n_roses  You Could Be Mine

# %%
df3 = full_discography_df2.merge(my_favourite_songs_df, how='inner', on=['artist', 'song'])
df3['key'] = df3.apply(lambda x: x['artist'] + '__' + '_'.join(x['album'].split()) + '__' + '_'.join(x['song'].split()), axis=1)
df3 = df3.set_index('key')
# df3.index

my_favourite_songs = list(df3.index)
my_favourite_songs
# Out:
# ['guns_n_roses__Use_Your_Illusion_II__You_Could_Be_Mine',
#  "queen__Greatest_Hits__Don't_Stop_Me_Now",
#  'queen__Innuendo__Under_Pressure',
#  'lana_del_rey__-__Blue_Jeans',
#  'rainbow__Rising__Stargazer']

# %%
def to_recommend_lyrics_by_set(df, target_list):
    vectorizer = TfidfVectorizer(max_df=0.7, min_df=2)
    vectorized_data = vectorizer.fit_transform(df['lyrics'])

    # Create Dataframe from TF-IDFarray
    tfidf_df = pd.DataFrame(vectorized_data.toarray(), columns=vectorizer.get_feature_names_out())

    # Assign the movie titles to the index and inspect
    tfidf_df.index = df.index

    # Create a subset of only the movies the user has enjoyed
    movies_enjoyed_df = tfidf_df.reindex(target_list)

    # Generate the user profile by finding the average scores of movies they enjoyed
    user_prof = movies_enjoyed_df.mean()

    # Find subset of tfidf_df that does not include movies in list_of_movies_enjoyed
    tfidf_subset_df = tfidf_df.drop(target_list, axis=0)

    # Calculate the cosine_similarity and wrap it in a DataFrame
    similarity_array = cosine_similarity(user_prof.values.reshape(1, -1), tfidf_subset_df)
    similarity_df = pd.DataFrame(similarity_array.T, index=tfidf_subset_df.index, columns=["similarity_score"])

    # Sort the values from high to low by the values in the similarity_score
    sorted_similarity_df = similarity_df.sort_values(by="similarity_score", ascending=False)

    return sorted_similarity_df

similar_by_set_df = to_recommend_lyrics_by_set(full_discography_df2, my_favourite_songs)

# %%
similar_df_head3 = top_of_similarity(similar_by_set_df, 0.3)
similar_df_head3.join(full_discography_df2).reset_index(drop=True)[['similarity_score','artist','album','song']]
# .iloc[:, :4]
# Out:
#    similarity_score        artist                album  \
# 0          0.409980         queen              Disc: 2
# 1          0.409980         queen    Greatest Hits III
# 2          0.409980         queen  Live At Wembley '86
# 3          0.409980         queen        Greatest Hits
# 4          0.313669     bob_dylan   Knocked Out Loaded
# 5          0.301823  guns_n_roses  Use Your Illusion I
#
#                          song
# 0  Another One Bites The Dust
# 1            We Will Rock You
# 2        We Are The Champions
# 3                Bicycle Race
# 4            Brownsville Girl
# 5                        Coma
