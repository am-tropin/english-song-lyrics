# %%
'''
https://www.allthelyrics.com/index
'''

# %% [markdown]
# # 1. Creation of a dictionary with lyrics

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
import re
import pandas as pd
import random
import time

# %%
artist_list = [
#     "elf",
#     "rainbow",
    "dio",
    "black_sabbath",
#     "within_temptation",
#     "depeche_mode",
#     "imagine_dragons",
#     "rainbow",
#     "u2",
#     "roxette",
#     "kasabian",  # a little
#     "blondie",
#     "doors",
#     "guns_n_roses",
#     "lana_del_rey",  # a little
#     "florence_the_machine",
#     "franz_ferdinand",
#     "bob_dylan",
#     "queen",
#     "muse",
#     "florence_the_machine"
]

# %%
def artist_discography_to_csv(artist):
    
    print()
    print(artist+':')
    print()
    url = 'https://www.allthelyrics.com/lyrics/' + artist
    req_announcement = requests.get(url)
    html_doc = req_announcement.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    kek = soup.find_all('div', attrs={'id': ['lyricslist-left', 'lyricslist-right']})

    discography = {}

    for k in kek:
        uuu = k.find_all('li')
        for u in uuu:
            discography[str.strip(u.text)] = {
                'link': "https://www.allthelyrics.com" + u.find('a')['href']
            }
#             print(u.text)
    
    # I need to make pauses to avoid blocking
    counter = 0

    for song in discography.keys():
        counter += 1
        print(counter, song)
        time.sleep(1)
        if counter % 10 == 0:
            time.sleep(4)

        req_announcement2 = requests.get(discography[song]['link'])
        html_doc2 = req_announcement2.text
        soup2 = BeautifulSoup(html_doc2, 'html.parser')

        kek2 = soup2.find_all('div', attrs={'class': ['content-text-album']})
        if kek2 == []:
            discography[song]['album'] = '-'
        else:
            album_str = kek2[0].text
            if re.findall(r'\:\s(.+)', album_str):
                album_str = re.findall(r'\:\s(.+)', album_str)[0]
            discography[song]['album'] = str.strip(album_str)

        kek3 = soup2.find_all('div', attrs={'class': ['content-text-inner']})
        if kek3 == []:
            discography[song]['lyrics'] = '-'
        else:
            discography[song]['lyrics'] = str.strip(kek3[0].text)

    discography_df = pd.DataFrame.from_dict({(i): discography[i] for i in discography.keys()}, orient='index')
    discography_df_2 = discography_df.reset_index().rename(columns={'index':'song'})
    
    albums = discography_df_2[['album','song']].groupby(['album'])['song'].count()
    print()
    print(albums)
    print()
    
    discography_df_2.to_csv('discography/' + artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8', index=False)
    
    return 1

# %%
for artist in artist_list:
    artist_discography_to_csv(artist)
# Out:
# dio:
#
# 1 Abraham, Martin, And John
# 2 All The Fools Sailed Away
# 3 Along Comes A Spider
# 4 Another Lie
# 5 As Long As It's Not About Love
# 6 Before The Fall
# 7 Better In The Dark
# 8 Between Two Hearts
# 9 Big Sister
# 10 Black
# 11 Blood From A Stone
# 12 Born On The Sun
# 13 Breathless
# 14 Bring Down The Rain
# 15 Caught In The Middle
# 16 Challis (Marry The Devil's Daughter)
# 17 Cold Feet
# 18 Death By Love
# 19 Don't Talk To Strangers
# 136 The Writ
# 137 Time Machine
# 138 Tomorrow's Dream
# 139 Too Late
# 140 Trashed
# 141 Turn To Stone
# 142 Turn Up The Night
# 143 Tv Crimes
# 144 Under The Sun
# 145 Under The Sun / Every Day Comes & Goes
# 146 Valhalla
# 147 Virtual Death
# 148 Voodoo
# 149 Walk Away
# 150 Walpurgis (Original Version Of War Pigs)
# 151 War Pigs
# 152 War Pigs (Alternate Version)
# 153 War Pigs Wall
# 154 Warning
# 155 Wasp
# 156 What's The Use?
# 157 Wheels Of Confusion
# 158 Wheels Of Confusion / The Straightener
# 159 When Death Calls
# 160 Who Are You?
# 161 Wicked World
# 162 Wishing Well
# 163 You Won't Change Me
# 164 Zero The Hero
#
# album
# -                                                 10
# Black Box: The Complete Original Black Sabbath     3
# Black Sabbath                                      8
# Born Again                                         7
# Cross Purposes                                    10
# Dehumanizer                                       10
# Eternal Idol                                       8
# Forbidden                                         10
# Greatest Hits                                      1
# Headless Cross                                    15
# Heaven Hell                                        7
# Live Evil                                          3
# Master Of Reality                                  6
# Mob Rules                                          5
# Never Say Die                                      8
# Paranoid                                           9
# Reunion                                            2
# Sabbath Bloody Sabbath                             7
# Sabotage                                           6
# Seventh Star                                       8
# Technical Ecstasy                                  8
# The Dio Years                                      1
# The Sabbath Stones                                 2
# Tyr                                                1
# Vol 4                                              9
# Name: song, dtype: int64

# %% [markdown]
# # ======== DRAFTS:

# %%
artist = "elf"

# done:

# dio
# black_sabbath
# rainbow
# elf

# "within_temptation"
# "depeche_mode"
# "imagine_dragons"
# "rainbow"
# "u2"
# "roxette"
# "kasabian"  # a little
# "blondie"
# "doors"
# "guns_n_roses"
# "lana_del_rey"  # a little
# "florence_the_machine"
# "franz_ferdinand"
# "bob_dylan"
# "queen"
# "muse"
# "florence_the_machine"

# %%
url = 'https://www.allthelyrics.com/lyrics/' + artist
req_announcement = requests.get(url)
html_doc = req_announcement.text
# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')
kek = soup.find_all('div', attrs={'id': ['lyricslist-left', 'lyricslist-right']})
# kek

# %%
discography = {}

for k in kek:
    uuu = k.find_all('li')
    for u in uuu:
        discography[str.strip(u.text)] = {
            'link': "https://www.allthelyrics.com" + u.find('a')['href']
        }
        print(u.text)
# Out:
# Ain't It All Amusing
# Annie New Orleans
# Black Swampy Water
# Blanche
# Carolina County Ball
# Dixie Lee Junction
# Do The Same Thing
# First Avenue
# Gambler, Gambler
# Good Time Music
# Happy
# I'm Coming Back For You
# L.a.59
# Liberty Road
# Love Me Like A Woman
# Never More
# Prentice Wood
# Rainbow
# Rocking Chair Rock 'n' Roll Blues
# Shotgun Boogie
# Sit Down Honey (Everything Will Be Alright)
# Streetwalker
# When She Smiles
# Wonderworld

# %%
# I need to make pauses to avoid blocking
counter = 0

for song in discography.keys():
    counter += 1
    print(counter, song)
    time.sleep(1)
    if counter % 10 == 0:
        time.sleep(4)

    req_announcement2 = requests.get(discography[song]['link'])
    html_doc2 = req_announcement2.text
    soup2 = BeautifulSoup(html_doc2, 'html.parser')
    
    kek2 = soup2.find_all('div', attrs={'class': ['content-text-album']})
    if kek2 == []:
        discography[song]['album'] = '-'
    else:
        album_str = kek2[0].text
        if re.findall(r'\:\s(.+)', album_str):
            album_str = re.findall(r'\:\s(.+)', album_str)[0]
        discography[song]['album'] = str.strip(album_str)
    
    kek3 = soup2.find_all('div', attrs={'class': ['content-text-inner']})
    if kek3 == []:
        discography[song]['lyrics'] = '-'
    else:
        discography[song]['lyrics'] = str.strip(kek3[0].text)
# Out:
# 1 Ain't It All Amusing
# 2 Annie New Orleans
# 3 Black Swampy Water
# 4 Blanche
# 5 Carolina County Ball
# 6 Dixie Lee Junction
# 7 Do The Same Thing
# 8 First Avenue
# 9 Gambler, Gambler
# 10 Good Time Music
# 11 Happy
# 12 I'm Coming Back For You
# 13 L.a.59
# 14 Liberty Road
# 15 Love Me Like A Woman
# 16 Never More
# 17 Prentice Wood
# 18 Rainbow
# 19 Rocking Chair Rock 'n' Roll Blues
# 20 Shotgun Boogie
# 21 Sit Down Honey (Everything Will Be Alright)
# 22 Streetwalker
# 23 When She Smiles
# 24 Wonderworld

# %%
discography_df = pd.DataFrame.from_dict({(i): discography[i] 
                           for i in discography.keys()},
                       orient='index')
# discography_df

discography_df_2 = discography_df.reset_index().rename(columns={'index':'song'})
discography_df_2.head()
# Out:
#                    song                                               link  \
# 0  Ain't It All Amusing  https://www.allthelyrics.com/lyrics/elf/aint_i...
# 1     Annie New Orleans  https://www.allthelyrics.com/lyrics/elf/annie_...
# 2    Black Swampy Water  https://www.allthelyrics.com/lyrics/elf/black_...
# 3               Blanche  https://www.allthelyrics.com/lyrics/elf/blanch...
# 4  Carolina County Ball  https://www.allthelyrics.com/lyrics/elf/caroli...
#
#                     album                                             lyrics
# 0    Carolina County Ball  Baby if you flatter me, you might get somewher...
# 1    Carolina County Ball  Aggravatin' Annie you're getting on my fanny\n...
# 2  Trying To Burn The Sun  Oh yeah\nUh back in the wood\nWhere it's good\...
# 3    Carolina County Ball  Rainy days, rainy days\nToo many rainy days\nI...
# 4    Carolina County Ball  Well just imagine my surprise to be there\nIf ...

# %%
# song_txt = discography_df_2[discography_df_2['song'] == song_title]['lyrics'].iloc[0]
# song_txt

# %%
# url = 'https://www.allthelyrics.com/lyrics/florence_the_machine/no_light_no_light-lyrics-1370537.html'
# req_announcement = requests.get(url)
# html_doc = req_announcement.text
# print(html_doc)

# %%
discography_df_2.to_csv('discography/' + artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8', index=False)

# %%
albums = discography_df_2[['album','song']].groupby(['album'])['song'].count()
albums
# Out:
# album
# Carolina County Ball      9
# Elf                       7
# Trying To Burn The Sun    8
# Name: song, dtype: int64
