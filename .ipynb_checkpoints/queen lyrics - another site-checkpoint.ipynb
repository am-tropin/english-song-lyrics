# %%
'''
https://www.allthelyrics.com/index
'''

# %% [markdown]
# # 1. Creation of a dictionary with lyrics

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
# import re
import pandas as pd
import random
import time

# %%
artist = 
# "depeche_mode"

# done:

# "imagine_dragons"
# "rainbow"
# "u2"
# "roxette"
# "kasabian"  # a little
# "blondie"
# "doors"
# "guns_n_roses"
# "lana_del_rey"  # a little
# "florence_the_machine"
# "franz_ferdinand"
# "bob_dylan"
# "queen"
# "muse"

# %%
url = 'https://www.allthelyrics.com/lyrics/' + artist
req_announcement = requests.get(url)
html_doc = req_announcement.text
# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')
kek = soup.find_all('div', attrs={'id': ['lyricslist-left', 'lyricslist-right']})
# kek

# %%
discography = {}

for k in kek:
    uuu = k.find_all('li')
    for u in uuu:
        discography[str.strip(u.text)] = {
            'link': "https://www.allthelyrics.com" + u.find('a')['href']
        }
        print(u.text)
# Out:
# 30 Lives
# All Eyes
# All For You
# America
# Amsterdam
# Battle Cry
# Bleeding Out
# Cha-Ching (Till We Grow Older)
# Clouds
# Cover Up
# Curse
# Darkness
# Demons
# Destination
# Drive
# Emma
# Every Night
# Fallen
# Gold
# Hear Me
# I Bet My Life
# I Don't Mind
# I Need A Minute
# It's Time
# Lay Me Down
# Leave Me
# Look How Far We've Come
# Lost Cause
# Monster
# My Fault
# Natural
# Nothing Left To Say
# On Top Of The World
# Pantomime
# Pistol Whip
# Radioactive
# Radioactive (Remix) (feat. Kendrick Lamar)
# Ready! Aim! Fire!
# Rocks
# Round And Round
# Selene
# The River
# Tiptoe
# Tokyo
# Underdog
# Uptight
# Warriors
# Who We Are
# Working Man

# %%
# discography

# %%
# I need to make pauses because of blocking
counter = 0

for song in discography.keys():
    counter += 1
    print(counter, song)
    time.sleep(1)
    if counter % 10 == 0:
        time.sleep(4)

    req_announcement2 = requests.get(discography[song]['link'])
    html_doc2 = req_announcement2.text
    soup2 = BeautifulSoup(html_doc2, 'html.parser')
    
    kek2 = soup2.find_all('div', attrs={'class': ['content-text-album']})
    if kek2 == []:
        discography[song]['album'] = '-'
    else:
        discography[song]['album'] = str.strip(kek2[0].text)
    
    kek3 = soup2.find_all('div', attrs={'class': ['content-text-inner']})
    if kek3 == []:
        discography[song]['lyrics'] = '-'
    else:
        discography[song]['lyrics'] = str.strip(kek3[0].text)
# Out:
# 1 30 Lives
# 2 All Eyes
# 3 All For You
# 4 America
# 5 Amsterdam
# 6 Battle Cry
# 7 Bleeding Out
# 8 Cha-Ching (Till We Grow Older)
# 9 Clouds
# 10 Cover Up
# 11 Curse
# 12 Darkness
# 13 Demons
# 14 Destination
# 15 Drive
# 16 Emma
# 17 Every Night
# 18 Fallen
# 19 Gold
# 20 Hear Me
# 21 I Bet My Life
# 22 I Don't Mind
# 23 I Need A Minute
# 24 It's Time
# 25 Lay Me Down
# 26 Leave Me
# 27 Look How Far We've Come
# 28 Lost Cause
# 29 Monster
# 30 My Fault
# 31 Natural
# 32 Nothing Left To Say
# 33 On Top Of The World
# 34 Pantomime
# 35 Pistol Whip
# 36 Radioactive
# 37 Radioactive (Remix) (feat. Kendrick Lamar)
# 38 Ready! Aim! Fire!
# 39 Rocks
# 40 Round And Round
# 41 Selene
# 42 The River
# 43 Tiptoe
# 44 Tokyo
# 45 Underdog
# 46 Uptight
# 47 Warriors
# 48 Who We Are
# 49 Working Man

# %%
# discography

# %%
discography_df = pd.DataFrame.from_dict({(i): discography[i] 
                           for i in discography.keys()},
                       orient='index')
# discography_df

discography_df_2 = discography_df.reset_index().rename(columns={'index':'song'})
discography_df_2
# Out:
#                                           song  \
# 0                                     30 Lives
# 1                                     All Eyes
# 2                                  All For You
# 3                                      America
# 4                                    Amsterdam
# 5                                   Battle Cry
# 6                                 Bleeding Out
# 7               Cha-Ching (Till We Grow Older)
# 8                                       Clouds
# 9                                     Cover Up
# 10                                       Curse
# 11                                    Darkness
# 12                                      Demons
# 13                                 Destination
# 14                                       Drive
# 15                                        Emma
# 16                                 Every Night
# 17                                      Fallen
# 18                                        Gold
# 19                                     Hear Me
# 20                               I Bet My Life
# 21                                I Don't Mind
# 22                             I Need A Minute
# 23                                   It's Time
# 24                                 Lay Me Down
# 25                                    Leave Me
# 26                     Look How Far We've Come
# 27                                  Lost Cause
# 28                                     Monster
# 29                                    My Fault
# 30                                     Natural
# 31                         Nothing Left To Say
# 32                         On Top Of The World
# 33                                   Pantomime
# 34                                 Pistol Whip
# 35                                 Radioactive
# 36  Radioactive (Remix) (feat. Kendrick Lamar)
# 37                           Ready! Aim! Fire!
# 38                                       Rocks
# 39                             Round And Round
# 40                                      Selene
# 41                                   The River
# 42                                      Tiptoe
# 43                                       Tokyo
# 44                                    Underdog
# 45                                     Uptight
# 46                                    Warriors
# 47                                  Who We Are
# 48                                 Working Man
#
#                                                  link                 album  \
# 0   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 1   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 2   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 3   https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 4   https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 5   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 6   https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 7   https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 8   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 9   https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 10  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 11  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 12  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 13  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 14  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 15  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 16  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 17  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 18  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 19  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 20  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 21  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 22  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 23  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 24  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 25  https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 26  https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 27  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 28  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 29  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 30          https://www.allthelyrics.com/node/1768728        Album: Origins
# 31  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 32  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 33  https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 34  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 35  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 36  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 37  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 38  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 39  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 40  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 41  https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 42  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 43  https://www.allthelyrics.com/lyrics/imagine_dr...      Album: It's Time
# 44  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
# 45  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 46  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 47  https://www.allthelyrics.com/lyrics/imagine_dr...                     -
# 48  https://www.allthelyrics.com/lyrics/imagine_dr...  Album: Night Visions
#
#                                                lyrics
# 0   Good morning my love\nIt's been a while since ...
# 1   Everything you say\nIs just a lie\nAnd now I'm...
# 2   I get caught in the water\nI get torn in the w...
# 3   Is this just an illusion\nThat I made inside m...
# 4   I'm sorry, mother... I'm sorry, I let you down...
# 5   Just one more time before I go\nI'll let you k...
# 6   I'm bleeding out\nSo if the last thing that I ...
# 7   I don't sleep so well at night\nWaiting up and...
# 8   Oh...!\nOh...!\nLooking at the lonely telegram...
# 9   There's lights that line these halls\nThat bec...
# 10  She barely knew your name\nHe was just a city,...
# 11  I can never leave you when you’re lying in the...
# 12  When the days are cold\nAnd the cards all fold...
# 13  I see the colors of the world—they're rearrang...
# 14  Get me right, all it takes is silent night\nI ...
# 15  Emma stood in front of me\nTellin' me what I'm...
# 16  I'm coming home to you\nEvery night...\nI'm th...
# 17  Run for cover\nMy sense of fear is running thi...
# 18  First comes the blessing of all that you've dr...
# 19  Try to hear my voice\nYou can leave, now it's ...
# 20  I know I took the path that you would never wa...
# 21  Did your mother like your Sunday dress\nAstrol...
# 22  Welcome to the land of fire\nI hope you brough...
# 23  So this is what you meant\nWhen you said that ...
# 24  Good morning, my love\nIt’s been a while since...
# 25  Take a look inside\nI've got nothing to hide -...
# 26  Take me on a whim\nIt's not the sun that provi...
# 27  Oh, dig my shallow grave\nIt's not me you'll s...
# 28  Ever since I could remember,\nEverything insid...
# 29  I took a walk on a Saturday night\nFog in the ...
# 30  Will you hold the line?\nWhen every one of the...
# 31  Who knows how long\nI've been awake now?\nThe ...
# 32  If you love somebody\nBetter tell them while t...
# 33  You've got me feeling like a pantomime\nThat's...
# 34  I can see clearly, I can see clearly [x3]\nWha...
# 35  Whoa, oh, oh\nWhoa, oh, oh\nWhoa, oh, oh\nWhoa...
# 36  [Verse 1]\nI'm waking up to ash and dust\nI wi...
# 37  Whoa\nWith our backs to the wall, the darkness...
# 38  Where do we go from here?\nWhere do we go from...
# 39  We are all living the same way, the same way\n...
# 40  To the top of all the world\nTo the tasteless ...
# 41  In the latest midnight hour\nWhen the world ha...
# 42  In the morning light let my roots take flight\...
# 43  Baby's got a lot of baggage...\nIt don't seem ...
# 44  Early morning take me over\nFather, father, fa...
# 45  Say goodbye to all your friends\nthey will mis...
# 46  As a child you would wait\nAnd watch from far ...
# 47  Up in the morning\nUp in the evening\nPicking ...
# 48  Shake it, shake it\nAnd we're moving again\nBe...

# %%
discography_df_2.to_csv(artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8', index=False)

# %%
albums = discography_df_2[['album','song']].groupby(['album'])['song'].count()
albums
# Out:
# album
# -                       27
# Album: It's Time         6
# Album: Night Visions    15
# Album: Origins           1
# Name: song, dtype: int64

# %% [markdown]
# # 2. Exercises with lyrics

# %%
'''
Choose the artist
'''

artist = 'florence_the_machine'

# %%
discography_df = pd.read_csv(artist+'_discography_allthelyrics.csv', sep='\t', encoding='utf-8')
# discography_df.head(15)

# %%
songs = list(discography_df['song'])

first_letter = ''
for s in songs:
    if s[0] != first_letter:
        first_letter = s[0]
        print()
        print(first_letter)
    print(s)
# Out:
# A
# Addicted To Love
# All This And Heaven Too
#
# B
# Between Two Lungs
# Blinding
# Breaking Down
#
# C
# Cosmic Love
#
# D
# Dog Days Are Over
# Drumming Song
#
# G
# Girl With One Eye
#
# H
# Heartlines
# Hurricane Drunk
#
# I
# I'm Not Calling You A Liar
#
# K
# Kiss With A Fist
#
# L
# Leave My Body
# Lover To Lover
#
# M
# My Boy Builds Coffins
#
# N
# Never Let Me Go
# No Light No Light
#
# O
# Only If For A Night
#
# R
# Rabbit Heart (Raise It Up)
#
# S
# Seven Devils
# Shake It Out
# Spectrum
#
# W
# What The Water Gave Me
#
# Y
# You've Got The Love

# %%
def add_gaps_to_lyrics(discography_df, song_title, string_frequency):
    
    song_txt = discography_df[discography_df['song'] == song_title]['lyrics'].iloc[0]
    # print(song_txt)
    song_strings = song_txt.split('\n')
    # song_strings

    string_counter = 0
    correct_answers = []
    gap_counter = 0
    
    fixed_song_list = []

    for s in song_strings:
        if string_counter % string_frequency == 0:
            gap_counter += 1
            words = s.split(' ')
            deleted_word_no = random.randint(0,len(words)-1)
            correct_answers.append(str.lower(words[deleted_word_no]))
            words[deleted_word_no] = "({0})".format(gap_counter) + '_'*len(words[deleted_word_no])
            fixed_song_list.append(' '.join(words))
#             print(' '.join(words))
        else:
            fixed_song_list.append(s)
#             print(s)
        string_counter += 1
    
    with open("LYRICS_WITH_GAPS.txt",'w') as file:
        pass
    with open('LYRICS_WITH_GAPS.txt', 'w') as f:
        for s in fixed_song_list:
            f.write(f"{s}\n")
    
    return correct_answers, gap_counter

# %%
def mark(a, b):
    if a == b:
        return '+'
    else:
        return ''

def answers_processing(correct_answers, gap_counter):

    my_answers = []

    for i in range(gap_counter):
#         print("{0}:".format(i+1))
        my_answers.append(str.lower(str.strip(input("{0}:\t ".format(i+1)))))

    print()
    correct_cnt = sum([1 for i in range(gap_counter) if correct_answers[i] == my_answers[i] ])
#     print("Results: {0} from {1} ({2}%)".format(correct_cnt, gap_counter, round(correct_cnt/gap_counter, 1)))

    shift = max(8, max(map(len, correct_answers)))
    print("\t correct:{0} - my answer:".format(' '*(shift-8)))

    for i in range(gap_counter):
        print("{0}  {1}\t {2} - {3}".format(i+1, mark(correct_answers[i],my_answers[i]), correct_answers[i] + ' '*(shift - len(correct_answers[i])), my_answers[i]))
    print()

    return "Results: {0} from {1} ({2}%)".format(correct_cnt, gap_counter, round(100 * correct_cnt/gap_counter, 1))

# %%
'''
Choose the song:
'''

song_title = 'No Light No Light'
string_frequency = 2

# %%
'''
Lyrics with gaps
'''

correct_answers, gap_counter = add_gaps_to_lyrics(discography_df, song_title, string_frequency)

# %%
'''
Fill the gaps
'''

print(answers_processing(correct_answers, gap_counter))
# Out:
# 1:	 another
# 2:	 you
# 3:	 night time
# 4:	 f
# 5:	 f
# 6:	 can
# 7:	 choose
# 8:	 no
# 9:	 me
# 10:	 k
# 11:	 day
# 12:	 it
# 13:	 d
# 14:	 f
# 15:	 f
# 16:	 f
# 17:	 f
# 18:	 f
# 19:	 f
# 20:	 f
# 21:	 f
# 22:	 f
# 23:	 f
# 24:	 f
# 25:	 f
# 26:	 f
# 27:	 f
# 28:	 f
# 29:	 f
# 30:	 f
# 31:	 f
# 32:	 f
# 33:	 f
# 34:	 f
#
# 	 correct:    - my answer:
# 1  	 are         - another
# 2  +	 you         - you
# 3  	 night-time  - night time
# 4  	 over        - f
# 5  	 heart       - f
# 6  	 could       - can
# 7  +	 choose      - choose
# 8  +	 no          - no
# 9  +	 me          - me
# 10  	 out         - k
# 11  	 plain       - day
# 12  +	 it          - it
# 13  	 get         - d
# 14  	 just        - f
# 15  	 of          - f
# 16  	 bright      - f
# 17  	 of          - f
# 18  	 i'd         - f
# 19  	 light       - f
# 20  	 leave       - f
# 21  	 you         - f
# 22  	 easy,       - f
# 23  	 but         - f
# 24  	 light       - f
# 25  	 the         - f
# 26  	 do          - f
# 27  	 light       - f
# 28  	 want        - f
# 29  	 but,        - f
# 30  	 a           - f
# 31  	 revelation. - f
# 32  	 get         - f
# 33  	 can't       - f
# 34  	 some        - f
#
# Results: 5 from 34 (0.1%)

# %%
'''
ДОРАБОТКИ:

- вернуть пустые строки между абзацами
- удалить знаки препинания из удаляемых слов
- сложить все дискографии в папку и перечислить их названия listdir

'''
