# %%
'''
https://www.allthelyrics.com/index
'''

# %% [markdown]
# # 1. Creation of a dictionary with links to all Queen sonds

# %%
import requests
from bs4 import Tag, NavigableString, BeautifulSoup
# import re
import pandas as pd
# import random
import time

# %%
artist = 
# "depeche_mode"

# done:

# "rainbow"
# "u2"
# "roxette"
# "kasabian"  # a little
# "blondie"
# "doors"
# "guns_n_roses"
# "lana_del_rey"  # a little
# "florence_the_machine"
# "franz_ferdinand"
# "bob_dylan"
# "queen"
# "muse"

# %%
url = 'https://www.allthelyrics.com/lyrics/' + artist
req_announcement = requests.get(url)
html_doc = req_announcement.text
# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')
kek = soup.find_all('div', attrs={'id': ['lyricslist-left', 'lyricslist-right']})
# kek

# %%
discography = {}

for k in kek:
    uuu = k.find_all('li')
    for u in uuu:
        discography[str.strip(u.text)] = {
            'link': "https://www.allthelyrics.com" + u.find('a')['href']
        }
        print(u.text)
# Out:
# A Light In The Black
# All Night Long
# Ariel
# Beethoven
# Black Masquerade
# Black Sheep Of The Family
# Bring On The Night
# Bring On The Night (Dream Chaser)
# Bye Bye Baby Goodbye
# Can't Happen Here
# Can't Let You Go
# Catch The Rainbow
# Cold Hearted Woman
# Danger Zone
# Death Alley Driver
# Desperate Heart
# Do You Close Your Eyes
# Drinking With The Devil
# Eyes Of Fire
# Eyes Of The World
# Fire Dance
# Fool For The Night
# Freedom Fighter
# Gates Of Babylon
# Hall Of The Mountain King
# Hunting Humans (Insatiable)
# I Surrender
# If You Don't Like Rock & Roll
# Jealous Lover
# Kill The King
# L. A. Connection
# Lady Of The Lake
# Long Live Rock'n'roll
# Lost In Hollywood
# Love's No Friend
# Magic
# Make Your Move
# Makin' Love
# Man On The Silver Mountain
# Midtown Tunnel Vision
# Miss Mistreated
# No Release
# No Time To Lose
# Power
# Rainbow Eyes
# Rock Fever
# Run With The Wolf
# Self Portrait
# Sensitive To Light
# Shed (Subtle)
# Silence
# Since You Been Gone
# Sixteenth Century Greensleeves
# Sixteenth Greenthleves
# Snake Charmer
# Spotlight Kid
# Stand And Fight
# Stargazer
# Starstruck
# Stone Cold
# Stranded
# Street Of Dreams
# Tarot Woman
# Tearin' Out My Heart
# The Shed
# The Temple Of The King
# Tite Squeeze
# Too Late For Tears
# Wolf To The Moon

# %%
# discography

# %%
# I need to make pauses because of blocking
counter = 0

for song in discography.keys():
    counter += 1
    print(counter, song)
    time.sleep(1)
    if counter % 10 == 0:
        time.sleep(4)

    req_announcement2 = requests.get(discography[song]['link'])
    html_doc2 = req_announcement2.text
    soup2 = BeautifulSoup(html_doc2, 'html.parser')
    
    kek2 = soup2.find_all('div', attrs={'class': ['content-text-album']})
    if kek2 == []:
        discography[song]['album'] = '-'
    else:
        discography[song]['album'] = str.strip(kek2[0].text)
    
    kek3 = soup2.find_all('div', attrs={'class': ['content-text-inner']})
    if kek3 == []:
        discography[song]['lyrics'] = '-'
    else:
        discography[song]['lyrics'] = str.strip(kek3[0].text)
# Out:
# 1 A Light In The Black
# 2 All Night Long
# 3 Ariel
# 4 Beethoven
# 5 Black Masquerade
# 6 Black Sheep Of The Family
# 7 Bring On The Night
# 8 Bring On The Night (Dream Chaser)
# 9 Bye Bye Baby Goodbye
# 10 Can't Happen Here
# 11 Can't Let You Go
# 12 Catch The Rainbow
# 13 Cold Hearted Woman
# 14 Danger Zone
# 15 Death Alley Driver
# 16 Desperate Heart
# 17 Do You Close Your Eyes
# 18 Drinking With The Devil
# 19 Eyes Of Fire
# 20 Eyes Of The World
# 21 Fire Dance
# 22 Fool For The Night
# 23 Freedom Fighter
# 24 Gates Of Babylon
# 25 Hall Of The Mountain King
# 26 Hunting Humans (Insatiable)
# 27 I Surrender
# 28 If You Don't Like Rock & Roll
# 29 Jealous Lover
# 30 Kill The King
# 31 L. A. Connection
# 32 Lady Of The Lake
# 33 Long Live Rock'n'roll
# 34 Lost In Hollywood
# 35 Love's No Friend
# 36 Magic
# 37 Make Your Move
# 38 Makin' Love
# 39 Man On The Silver Mountain
# 40 Midtown Tunnel Vision
# 41 Miss Mistreated
# 42 No Release
# 43 No Time To Lose
# 44 Power
# 45 Rainbow Eyes
# 46 Rock Fever
# 47 Run With The Wolf
# 48 Self Portrait
# 49 Sensitive To Light
# 50 Shed (Subtle)
# 51 Silence
# 52 Since You Been Gone
# 53 Sixteenth Century Greensleeves
# 54 Sixteenth Greenthleves
# 55 Snake Charmer
# 56 Spotlight Kid
# 57 Stand And Fight
# 58 Stargazer
# 59 Starstruck
# 60 Stone Cold
# 61 Stranded
# 62 Street Of Dreams
# 63 Tarot Woman
# 64 Tearin' Out My Heart
# 65 The Shed
# 66 The Temple Of The King
# 67 Tite Squeeze
# 68 Too Late For Tears
# 69 Wolf To The Moon

# %%
# discography

# %%
discography_df = pd.DataFrame.from_dict({(i): discography[i] 
                           for i in discography.keys()},
                       orient='index')
# discography_df

discography_df_2 = discography_df.reset_index().rename(columns={'index':'song'})
discography_df_2
# Out:
#                       song                                               link  \
# 0     A Light In The Black  https://www.allthelyrics.com/lyrics/rainbow/a_...
# 1           All Night Long  https://www.allthelyrics.com/lyrics/rainbow/al...
# 2                    Ariel  https://www.allthelyrics.com/lyrics/rainbow/ar...
# 3                Beethoven  https://www.allthelyrics.com/lyrics/rainbow/be...
# 4         Black Masquerade  https://www.allthelyrics.com/lyrics/rainbow/bl...
# ..                     ...                                                ...
# 64                The Shed  https://www.allthelyrics.com/lyrics/rainbow/th...
# 65  The Temple Of The King  https://www.allthelyrics.com/lyrics/rainbow/th...
# 66            Tite Squeeze  https://www.allthelyrics.com/lyrics/rainbow/ti...
# 67      Too Late For Tears  https://www.allthelyrics.com/lyrics/rainbow/to...
# 68        Wolf To The Moon  https://www.allthelyrics.com/lyrics/rainbow/wo...
#
#                                album  \
# 0                      Album: Rising
# 1               Album: Down To Earth
# 2          Album: Stranger in Us All
# 3                                  -
# 4          Album: Stranger in Us All
# ..                               ...
# 64      Album: Long Live Rock'n'Roll
# 65                    Album: Rainbow
# 66  Album: Straight between the Eyes
# 67         Album: Stranger in Us All
# 68         Album: Stranger in Us All
#
#                                                lyrics
# 0   Can't forget his face\nWhat a lonely place\nHa...
# 1   You're walking up with your eyes on me\nIt's l...
# 2   I search for her in the dead of night\nA silho...
# 3   Beethoven's Ninth Symphony\nmaking of...\nadri...
# 4   I know the key to secrets never told, they're ...
# ..                                                ...
# 64  I'm like a freight train feelin? no pain\nI ne...
# 65  One day in the year of the fox\nCame a time re...
# 66  I ain't lyin' to you baby... I hope you don't ...
# 67  Well I'm moving faster close to the edge\nAs I...
# 68  With a rebel mind and a gypsy heart\nNo place ...
#
# [69 rows x 4 columns]

# %%
discography_df_2.to_csv(artist + '_discography_allthelyrics.csv', sep='\t', encoding='utf-8', index=False)

# %%
albums = discography_df_2[['album','song']].groupby(['album'])['song'].count()
albums
# Out:
# album
# -                                      2
# Album: Bent out of Shape               8
# Album: Difficult to Cure               7
# Album: Down To Earth                   8
# Album: Long Live Rock'n'Roll           9
# Album: Rainbow                         8
# Album: Rainbow Rising                  1
# Album: Rising                          5
# Album: Ritchie Blackmore's Rainbow     1
# Album: Straight between the Eyes      10
# Album: Stranger in Us All              9
# Album: Very Best of Rainbow            1
# Name: song, dtype: int64
